# %%
import pandas as pd

# %%
# Hour of day of the most registration
df = pd.read_csv('Datasets/customers.csv')
df
# Out:
#    id              name                               email  \
# 0   1    Johnson Bassey                 jbassey@example.com
# 1   2         Eben Ekoh             ekoh4Life@fakeemail.org
# 2   3     Gbade Tenaike  newcarsolutions@mainnetwork.com.ng
# 3   4        Orji Mezie                orjinonso@mailer.com
# 4   5    Lemuel Solomon       papasolo1@anotherfakeemail.co
# 5   6  Arinze Kwankwaso                                 NaN
# 6   7       Elena Adams     adamu.elena@trucksforsale.co.uk
# 7   8      Orji Nwankwo             nwankwo123111@gmail.com
# 8   9       Eben Winter      wintershows@lookwarmprinter.ng
# 9  10        Ali Sodipo                                 NaN
#
#          registered_at
# 0  2022-05-03 10:05:45
# 1  2022-02-17 08:19:00
# 2  2022-01-01 22:19:00
# 3  2022-03-14 08:58:21
# 4  2022-05-03 10:05:45
# 5  2022-02-28 18:00:06
# 6  2022-03-10 11:12:00
# 7  2022-03-14 08:58:21
# 8  2022-02-17 08:19:00
# 9  2022-03-14 08:58:21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             10 non-null     int64
#  1   name           10 non-null     object
#  2   email          8 non-null      object
#  3   registered_at  10 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 448.0+ bytes

# %%
df['registered_at'] = pd.to_datetime(df['registered_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             10 non-null     int64
#  1   name           10 non-null     object
#  2   email          8 non-null      object
#  3   registered_at  10 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 448.0+ bytes

# %%
df['registered_year'] = df['registered_at'].dt.year
df['registered_month'] = df['registered_at'].dt.month
df['registered_day'] = df['registered_at'].dt.day
# df['registered_hour'] = df['registered_at'].dt.hour

# %%
df['registered_hour'] = df['registered_at'].astype(str).apply(lambda x: x[11:13]).astype(int)

# %%
df
# Out:
#    id              name                               email  \
# 0   1    Johnson Bassey                 jbassey@example.com
# 1   2         Eben Ekoh             ekoh4Life@fakeemail.org
# 2   3     Gbade Tenaike  newcarsolutions@mainnetwork.com.ng
# 3   4        Orji Mezie                orjinonso@mailer.com
# 4   5    Lemuel Solomon       papasolo1@anotherfakeemail.co
# 5   6  Arinze Kwankwaso                                 NaN
# 6   7       Elena Adams     adamu.elena@trucksforsale.co.uk
# 7   8      Orji Nwankwo             nwankwo123111@gmail.com
# 8   9       Eben Winter      wintershows@lookwarmprinter.ng
# 9  10        Ali Sodipo                                 NaN
#
#         registered_at  registered_year  registered_month  registered_day  \
# 0 2022-05-03 10:05:45             2022                 5               3
# 1 2022-02-17 08:19:00             2022                 2              17
# 2 2022-01-01 22:19:00             2022                 1               1
# ...

# %%
df['email'] = df['email'].fillna('Not provided')

# %%
df
# Out:
#    id              name                               email  \
# 0   1    Johnson Bassey                 jbassey@example.com
# 1   2         Eben Ekoh             ekoh4Life@fakeemail.org
# 2   3     Gbade Tenaike  newcarsolutions@mainnetwork.com.ng
# 3   4        Orji Mezie                orjinonso@mailer.com
# 4   5    Lemuel Solomon       papasolo1@anotherfakeemail.co
# 5   6  Arinze Kwankwaso                        Not provided
# 6   7       Elena Adams     adamu.elena@trucksforsale.co.uk
# 7   8      Orji Nwankwo             nwankwo123111@gmail.com
# 8   9       Eben Winter      wintershows@lookwarmprinter.ng
# 9  10        Ali Sodipo                        Not provided
#
#         registered_at  registered_year  registered_month  registered_day  \
# 0 2022-05-03 10:05:45             2022                 5               3
# 1 2022-02-17 08:19:00             2022                 2              17
# 2 2022-01-01 22:19:00             2022                 1               1
# ...

# %%
df[['first_name', 'last_name']] = df['name'].str.split(' ', expand=True)

# %%
df
# Out:
#    id              name                               email  \
# 0   1    Johnson Bassey                 jbassey@example.com
# 1   2         Eben Ekoh             ekoh4Life@fakeemail.org
# 2   3     Gbade Tenaike  newcarsolutions@mainnetwork.com.ng
# 3   4        Orji Mezie                orjinonso@mailer.com
# 4   5    Lemuel Solomon       papasolo1@anotherfakeemail.co
# 5   6  Arinze Kwankwaso                        Not provided
# 6   7       Elena Adams     adamu.elena@trucksforsale.co.uk
# 7   8      Orji Nwankwo             nwankwo123111@gmail.com
# 8   9       Eben Winter      wintershows@lookwarmprinter.ng
# 9  10        Ali Sodipo                        Not provided
#
#         registered_at  registered_year  registered_month  registered_day  \
# 0 2022-05-03 10:05:45             2022                 5               3
# 1 2022-02-17 08:19:00             2022                 2              17
# 2 2022-01-01 22:19:00             2022                 1               1
# ...

# %%
list(df.columns)
# Out:
# ['id',
#  'name',
#  'email',
#  'registered_at',
#  'registered_year',
#  'registered_month',
#  'registered_day',
#  'registered_hour',
#  'first_name',
#  'last_name']

# %%
df = df[['id', 'first_name', 'last_name', 'email', 'registered_at', 'registered_year', 'registered_month', 'registered_day', 'registered_hour']]

# %%
df
# Out:
#    id first_name  last_name                               email  \
# 0   1    Johnson     Bassey                 jbassey@example.com
# 1   2       Eben       Ekoh             ekoh4Life@fakeemail.org
# 2   3      Gbade    Tenaike  newcarsolutions@mainnetwork.com.ng
# 3   4       Orji      Mezie                orjinonso@mailer.com
# 4   5     Lemuel    Solomon       papasolo1@anotherfakeemail.co
# 5   6     Arinze  Kwankwaso                        Not provided
# 6   7      Elena      Adams     adamu.elena@trucksforsale.co.uk
# 7   8       Orji    Nwankwo             nwankwo123111@gmail.com
# 8   9       Eben     Winter      wintershows@lookwarmprinter.ng
# 9  10        Ali     Sodipo                        Not provided
#
#         registered_at  registered_year  registered_month  registered_day  \
# 0 2022-05-03 10:05:45             2022                 5               3
# 1 2022-02-17 08:19:00             2022                 2              17
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                10 non-null     int64
#  1   first_name        10 non-null     object
#  2   last_name         10 non-null     object
#  3   email             10 non-null     object
#  4   registered_at     10 non-null     datetime64[ns]
#  5   registered_year   10 non-null     int32
#  6   registered_month  10 non-null     int32
#  7   registered_day    10 non-null     int32
#  8   registered_hour   10 non-null     int64
# dtypes: datetime64[ns](1), int32(3), int64(2), object(3)
# memory usage: 728.0+ bytes

# %% [markdown]
# ##Q2. Monthly and Quarterly gains and losses

# %%
tdf = pd.read_csv('Datasets/transactions.csv')

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1012 entries, 0 to 1011
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1012 non-null   int64
#  1   customer_id  1012 non-null   int64
#  2   item_id      1012 non-null   int64
#  3   date         1012 non-null   object
#  4   bank_id      1012 non-null   object
#  5   qty          1012 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.6+ KB

# %%
tdf
# Out:
#                 id  customer_id  item_id        date  \
# 0     987654674568            5   189975  2022-10-01
# 1     987654674569            3   189979  2022-10-24
# 2     987654674570            3   189972  2022-10-05
# 3     987654674571            6   189976  2022-10-20
# 4     987654674572            3   189976  2022-10-25
# ...            ...          ...      ...         ...
# 1007  987654675575            8   189968  2022-10-25
# 1008  987654675576            8   189969  2022-10-25
# 1009  987654675577            8   189969  2022-10-25
# 1010  987654675578            8   189969  2022-10-25
# 1011  987654675579            8   189968  2022-10-25
#
#                                bank_id  qty
# 0     C033E8B707130D6E9EDAA5FBD26E49FA    5
# 1     202EE94EE8FE166F80C07342465940C2    3
# 2     B0C19A0B2BB6055BE0FDEB9280B13F70    4
# 3     C033E8B707130D6E9EDAA5FBD26E49FA    2
# 4     809AF35745782C14F2457E6B1128E8CB    3
# ...                                ...  ...
# ...

# %%
tdf['date'] = pd.to_datetime(tdf['date'])
tdf
# Out:
#                 id  customer_id  item_id       date  \
# 0     987654674568            5   189975 2022-10-01
# 1     987654674569            3   189979 2022-10-24
# 2     987654674570            3   189972 2022-10-05
# 3     987654674571            6   189976 2022-10-20
# 4     987654674572            3   189976 2022-10-25
# ...            ...          ...      ...        ...
# 1007  987654675575            8   189968 2022-10-25
# 1008  987654675576            8   189969 2022-10-25
# 1009  987654675577            8   189969 2022-10-25
# 1010  987654675578            8   189969 2022-10-25
# 1011  987654675579            8   189968 2022-10-25
#
#                                bank_id  qty
# 0     C033E8B707130D6E9EDAA5FBD26E49FA    5
# 1     202EE94EE8FE166F80C07342465940C2    3
# 2     B0C19A0B2BB6055BE0FDEB9280B13F70    4
# 3     C033E8B707130D6E9EDAA5FBD26E49FA    2
# 4     809AF35745782C14F2457E6B1128E8CB    3
# ...                                ...  ...
# ...

# %%
tdf['transaction_year'] = tdf['date'].dt.year
tdf['transaction_month'] = tdf['date'].dt.month
tdf['transaction_day'] = tdf['date'].dt.day

# %%
tdf
# Out:
#                 id  customer_id  item_id       date  \
# 0     987654674568            5   189975 2022-10-01
# 1     987654674569            3   189979 2022-10-24
# 2     987654674570            3   189972 2022-10-05
# 3     987654674571            6   189976 2022-10-20
# 4     987654674572            3   189976 2022-10-25
# ...            ...          ...      ...        ...
# 1007  987654675575            8   189968 2022-10-25
# 1008  987654675576            8   189969 2022-10-25
# 1009  987654675577            8   189969 2022-10-25
# 1010  987654675578            8   189969 2022-10-25
# 1011  987654675579            8   189968 2022-10-25
#
#                                bank_id  qty  transaction_year  \
# 0     C033E8B707130D6E9EDAA5FBD26E49FA    5              2022
# 1     202EE94EE8FE166F80C07342465940C2    3              2022
# 2     B0C19A0B2BB6055BE0FDEB9280B13F70    4              2022
# 3     C033E8B707130D6E9EDAA5FBD26E49FA    2              2022
# ...

# %%
tdf = tdf.rename(columns={'date': 'transaction_date'})

# %%
list(tdf.columns)
# Out:
# ['id',
#  'customer_id',
#  'item_id',
#  'transaction_date',
#  'bank_id',
#  'qty',
#  'transaction_year',
#  'transaction_month',
#  'transaction_day']

# %%
tdf = tdf[['id',
 'customer_id',
 'item_id',
 'bank_id',
 'qty',
 'transaction_date',
 'transaction_year',
 'transaction_month',
 'transaction_day']]

# %%
tdf
# Out:
#                 id  customer_id  item_id                           bank_id  \
# 0     987654674568            5   189975  C033E8B707130D6E9EDAA5FBD26E49FA
# 1     987654674569            3   189979  202EE94EE8FE166F80C07342465940C2
# 2     987654674570            3   189972  B0C19A0B2BB6055BE0FDEB9280B13F70
# 3     987654674571            6   189976  C033E8B707130D6E9EDAA5FBD26E49FA
# 4     987654674572            3   189976  809AF35745782C14F2457E6B1128E8CB
# ...            ...          ...      ...                               ...
# 1007  987654675575            8   189968  C033E8B707130D6E9EDAA5FBD26E49FA
# 1008  987654675576            8   189969  B0C19A0B2BB6055BE0FDEB9280B13F70
# 1009  987654675577            8   189969  C033E8B707130D6E9EDAA5FBD26E49FA
# 1010  987654675578            8   189969  B0C19A0B2BB6055BE0FDEB9280B13F70
# 1011  987654675579            8   189968  C033E8B707130D6E9EDAA5FBD26E49FA
#
#       qty transaction_date  transaction_year  transaction_month  \
# ...

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1012 entries, 0 to 1011
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1012 non-null   int64
#  1   customer_id        1012 non-null   int64
#  2   item_id            1012 non-null   int64
#  3   bank_id            1012 non-null   object
#  4   qty                1012 non-null   int64
#  5   transaction_date   1012 non-null   datetime64[ns]
#  6   transaction_year   1012 non-null   int32
#  7   transaction_month  1012 non-null   int32
#  8   transaction_day    1012 non-null   int32
# dtypes: datetime64[ns](1), int32(3), int64(4), object(1)
# memory usage: 59.4+ KB

# %% [markdown]
# ### check other tables

# %%
idf = pd.read_csv('Datasets/exchange_rates.csv')

# %%
idf
# Out:
#            date                           bank_id    rate
# 0    2022-10-01  809AF35745782C14F2457E6B1128E8CB  543.76
# 1    2022-10-02  809AF35745782C14F2457E6B1128E8CB  570.78
# 2    2022-10-03  809AF35745782C14F2457E6B1128E8CB  576.73
# 3    2022-10-04  809AF35745782C14F2457E6B1128E8CB  588.42
# 4    2022-10-05  809AF35745782C14F2457E6B1128E8CB  563.42
# ..          ...                               ...     ...
# 150  2022-10-27  202EE94EE8FE166F80C07342465940C2  573.07
# 151  2022-10-28  202EE94EE8FE166F80C07342465940C2  583.06
# 152  2022-10-29  202EE94EE8FE166F80C07342465940C2  589.87
# 153  2022-10-30  202EE94EE8FE166F80C07342465940C2  570.05
# 154  2022-10-31  202EE94EE8FE166F80C07342465940C2  591.66
#
# [155 rows x 3 columns]

# %%
idf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     155 non-null    object
#  1   bank_id  155 non-null    object
#  2   rate     155 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 3.8+ KB

# %%
s3_path = 's3://{}/{}.csv'

# %%
bucket_name = 'meiz'

# %%
df = pd.read_csv('s3://weserveadeleke/agents.csv', storage_options={
        'key': '***REMOVED***', 'secret': '***REMOVED***'
    })

# %%
df.to_csv('s3://meiz/agents.csv', storage_options={
        'key': '***REMOVED***', 'secret': '***REMOVED***'
    })
